# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\norbe\documents\work\essentialmathfordatascience\venv\lib\site-packages (from scipy) (2.1.2)
# Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#     --------------------------------------- 1.0/44.5 MB 6.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.4/44.5 MB 7.0 MB/s eta 0:00:07
#    --- ------------------------------------ 3.9/44.5 MB 7.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.5/44.5 MB 7.2 MB/s eta 0:00:06
#    ------ --------------------------------- 7.3/44.5 MB 7.4 MB/s eta 0:00:06
#    -------- ------------------------------- 8.9/44.5 MB 7.5 MB/s eta 0:00:05
#    --------- ------------------------------ 10.7/44.5 MB 7.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 11.8/44.5 MB 7.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 12.1/44.5 MB 6.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 12.6/44.5 MB 6.1 MB/s eta 0:00:06
#    ------------ --------------------------- 14.2/44.5 MB 6.2 MB/s eta 0:00:05
#    -------------- ------------------------- 15.7/44.5 MB 6.3 MB/s eta 0:00:05
#    --------------- ------------------------ 17.3/44.5 MB 6.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 17.8/44.5 MB 6.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 18.4/44.5 MB 5.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 19.9/44.5 MB 6.0 MB/s eta 0:00:05
#    ------------------- -------------------- 21.8/44.5 MB 6.1 MB/s eta 0:00:04
#    -------------------- ------------------- 23.3/44.5 MB 6.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 24.9/44.5 MB 6.3 MB/s eta 0:00:04
#    ------------------------ --------------- 26.7/44.5 MB 6.4 MB/s eta 0:00:03
#    ------------------------- -------------- 28.3/44.5 MB 6.4 MB/s eta 0:00:03
#    -------------------------- ------------- 29.9/44.5 MB 6.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 31.5/44.5 MB 6.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.3/44.5 MB 6.6 MB/s eta 0:00:02
#    ------------------------------- -------- 34.9/44.5 MB 6.7 MB/s eta 0:00:02
#    --------------------------------- ------ 36.7/44.5 MB 6.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.5/44.5 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------ --- 40.6/44.5 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 41.4/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.14.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.stats import binom

n = 10
p = 0.9

for k in range(n + 1):
    prawdopodobienstwo = binom.pmf(k, n, p)
    print("{0} - {1}".format(k, prawdopodobienstwo))
# Out:
# 0 - 9.999999999999977e-11
# 1 - 8.999999999999976e-09
# 2 - 3.6449999999999933e-07
# 3 - 8.747999999999988e-06
# 4 - 0.00013778099999999974
# 5 - 0.0014880347999999982
# 6 - 0.011160260999999989
# 7 - 0.05739562799999997
# 8 - 0.1937102444999998
# 9 - 0.38742048899999976
# 10 - 0.34867844010000015

# %%
from scipy.stats import binom

n = 10
p = 0.5

for k in range(n + 1):
    prawdopodobienstwo = binom.pmf(k, n, p)
    print("{0} - {1}".format(k, prawdopodobienstwo))
# Out:
# 0 - 0.000976562499999999
# 1 - 0.009765625000000003
# 2 - 0.04394531250000005
# 3 - 0.11718749999999999
# 4 - 0.2050781249999999
# 5 - 0.24609375
# 6 - 0.2050781249999999
# 7 - 0.11718749999999996
# 8 - 0.04394531250000005
# 9 - 0.009765625000000003
# 10 - 0.0009765625

# %%
from scipy.stats import binom

n = 100
p = 0.5

for k in range(n + 1):
    prawdopodobienstwo = binom.pmf(k, n, p)
    print("{0} - {1}".format(k, prawdopodobienstwo))
# Out:
# 0 - 7.888609052210195e-31
# 1 - 7.888609052210033e-29
# 2 - 3.904861480844e-27
# 3 - 1.2755880837423788e-25
# 4 - 3.0933011030753035e-24
# 5 - 5.93913811790456e-23
# 6 - 9.403635353348678e-22
# 7 - 1.2627738903068486e-20
# 8 - 1.4679746474816943e-19
# 9 - 1.5005963063146147e-18
# 10 - 1.3655426387463141e-17
# 11 - 1.1172621589742657e-16
# 12 - 8.286361012392431e-16
# 13 - 5.609228993004058e-15
# 14 - 3.4857351599382284e-14
# 15 - 1.998488158364591e-13
# 16 - 1.0616968341311874e-12
# 17 - 5.246031415707035e-12
# 18 - 2.4190033750204573e-11
# 19 - 1.0439909302719996e-10
# 20 - 4.2281632676015583e-10
# 21 - 1.6107288638482218e-09
# 22 - 5.7839809201822354e-09
# 23 - 1.9615239642357247e-08
# 24 - 6.293222718589586e-08
# 25 - 1.913139706451239e-07
# 26 - 5.518672230147833e-07
# 27 - 1.5125249815960556e-06
# 28 - 3.943368702018307e-06
# 29 - 9.790432639493727e-06
# 30 - 2.3170690580135153e-05
# 31 - 5.232091421320834e-05
# 32 - 0.00011281697127223023
# 33 - 0.00023247133474277808
# 34 - 0.00045810527728723955
# 35 - 0.0008638556657416446
# 36 - 0.0015597393964779781
# 37 - 0.0026979276047186694
# 38 - 0.00447287997624413
# 39 - 0.0071107322699265375
# 40 - 0.010843866711637978
# 41 - 0.015869073236543345
# 42 - 0.022292269546572836
# 43 - 0.03006864264421454
# 44 - 0.03895255978909615
# 45 - 0.04847429662643071
# 46 - 0.057958398140297664
# 47 - 0.0665904999909802
# 48 - 0.07352701040670744
# 49 - 0.07802866410507718
# 50 - 0.07958923738717875
# 51 - 0.07802866410507718
# 52 - 0.07352701040670744
# 53 - 0.06659049999098021
# 54 - 0.057958398140297664
# 55 - 0.04847429662643072
# 56 - 0.03895255978909615
# 57 - 0.030068642644214497
# 58 - 0.02229226954657277
# 59 - 0.015869073236543345
# 60 - 0.010843866711637958
# 61 - 0.0071107322699265375
# 62 - 0.004472879976244131
# 63 - 0.0026979276047186694
# 64 - 0.0015597393964779781
# 65 - 0.0008638556657416446
# 66 - 0.00045810527728723955
# 67 - 0.00023247133474277806
# 68 - 0.00011281697127223023
# 69 - 5.232091421320834e-05
# 70 - 2.317069058013515e-05
# 71 - 9.790432639493727e-06
# 72 - 3.943368702018307e-06
# 73 - 1.5125249815960556e-06
# 74 - 5.518672230147833e-07
# 75 - 1.913139706451239e-07
# 76 - 6.293222718589586e-08
# 77 - 1.9615239642357247e-08
# 78 - 5.7839809201822354e-09
# 79 - 1.6107288638482218e-09
# 80 - 4.2281632676015583e-10
# 81 - 1.0439909302719997e-10
# 82 - 2.4190033750204573e-11
# 83 - 5.246031415707035e-12
# 84 - 1.0616968341311874e-12
# 85 - 1.9984881583645913e-13
# 86 - 3.4857351599382284e-14
# 87 - 5.609228993004059e-15
# 88 - 8.28636101239243e-16
# 89 - 1.1172621589742654e-16
# 90 - 1.3655426387463142e-17
# 91 - 1.5005963063146145e-18
# 92 - 1.4679746474816943e-19
# 93 - 1.2627738903068486e-20
# 94 - 9.403635353348678e-22
# 95 - 5.939138117904561e-23
# 96 - 3.0933011030753035e-24
# 97 - 1.2755880837423786e-25
# 98 - 3.904861480844e-27
# 99 - 7.888609052210032e-29
# 100 - 7.888609052210118e-31

# %%
from scipy.stats import beta

a = 8
b = 2

p = beta.cdf(.90, a, b)

print(p) # 0.7748409780000001
# Out:
# 0.7748409780000002
